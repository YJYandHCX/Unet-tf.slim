# %%
import numpy as np

# %%
import TEST

# %%
tt = TEST.test()
# Out:
# WARNING:tensorflow:From C:\Users\hcxshizhu\Unet-tf.slim\Net.py:69: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# INFO:tensorflow:Restoring parameters from ./save/model.ckpt-1303
# OK

# %%
pic_path = './test/json/'
label_path = './test/label/'
rrr = np.zeros([10],dtype = np.float32)

# %%
for i in range(1,11):
    im_p = pic_path+str(i)+'.jpg'
    la_p = label_path+str(i)+'.pkl'
    sa1_p = './test/res/hr' + str(i)+'.jpg'
    sa2_p = './test/res/sc' + str(i) +'.jpg'
    
    res = tt.save_and_show_res(im_p,sa1_p,sa2_p)
    res = tt.show_pre(res,la_p)
    rrr[i-1] = res
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.7249888888888889
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.6405444444444445
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.6328333333333334
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.5928777777777777
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.38266666666666665
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.5842666666666667
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.6057555555555556
# ...

# %%
kkk = 0.0
for i in range(10):
    kkk = kkk + rrr[i]
print (kkk/10.0)
# Out:
# 0.6042344540357589
